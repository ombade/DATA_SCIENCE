# %%
import pandas as pd  # for importing the padas and making is aslicing as pd 
pd.read_csv("services.csv") # to read the data from the csv file 
df = pd.read_csv("services.csv")  # to store the data of the file into variable 
df.head(5)  # to show the data of the first 5 recordes in csv 
df.tail(5) # to show the data of last 5 record 
df.columns # to get the columns of the dataframe
df.columns[2] # to  get the column of the 2 nd index or value provided into the bracate 
df.dtypes #to get the data types of the colums in the data frames
df['program_id'] # to get the data of the given column 
type(df['program_id']) # to get the type of the data column
df[['program_id', 'accepted_payments', 'alternate_name']] #to show the data from the multipal column
df2 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")  # to read the data csv from external website
url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html") # to load the data from the external website using pandas
# the above url_data return the data into list (if there are 3 tables in website it will  give three indexed list )
df3 =url_data[0] # to convert the list data into dataframe
df3.to_csv("players_data.csv",index=False) # to convert the given data frame into csv into local system in players_data.csv
# Out:
#     program_id         accepted_payments         alternate_name
# 0          NaN                       NaN                    NaN
# 1          NaN                       NaN                    NaN
# 2          NaN                       NaN                    NaN
# 3          NaN                       NaN                    NaN
# 4          NaN                       NaN                    NaN
# 5          NaN                       NaN                    NaN
# 6          NaN                       NaN                    NaN
# 7          NaN                       NaN                    NaN
# 8          NaN                       NaN                    NaN
# 9          NaN                       NaN                    NaN
# 10         NaN                       NaN                    NaN
# 11         NaN                       NaN                    NaN
# 12         NaN                       NaN                    NaN
# 13         NaN                       NaN                    NaN
# ...

# %%
import pandas as pd

# %%
df =pd.read_csv("services.csv")
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_csv("players_data.csv",index=False)

print(df.dtypes)
df.head(34)
df.describe()
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# ...

# %%
df.tail(4)
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
data_col = (df.columns)

# %%
data_col[2]
df['program_id']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Om Bade\Desktop\DATA_SCIENCE\08_ML_toolbox_Pandas\pandas_pr_part1.ipynb Cell 8 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Om%20Bade/Desktop/DATA_SCIENCE/08_ML_toolbox_Pandas/pandas_pr_part1.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> data_col[2]
#       <a href='vscode-notebook-cell:/c%3A/Users/Om%20Bade/Desktop/DATA_SCIENCE/08_ML_toolbox_Pandas/pandas_pr_part1.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> df['program_id']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Om%20Bade/Desktop/DATA_SCIENCE/08_ML_toolbox_Pandas/pandas_pr_part1.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> df.type()
#
# File c:\Users\Om Bade\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5487, in NDFrame.__getattr__(self, name)
#    5480 if (
#    5481     name not in self._internal_names_set
# ...

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.head(234)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 229          230         0       3
# 230          231         1       1
# 231          232         0       3
# 232          233         0       2
# 233          234         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
