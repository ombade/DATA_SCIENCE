# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Om Bade\Desktop\DATA_SCIENCE\09_ML_toolbox_numpy_&_visulization\bokeh_hindi.ipynb Cell 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Om%20Bade/Desktop/DATA_SCIENCE/09_ML_toolbox_numpy_%26_visulization/bokeh_hindi.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import bokeh.io
#       <a href='vscode-notebook-cell:/c%3A/Users/Om%20Bade/Desktop/DATA_SCIENCE/09_ML_toolbox_numpy_%26_visulization/bokeh_hindi.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import bokeh.plotting
#       <a href='vscode-notebook-cell:/c%3A/Users/Om%20Bade/Desktop/DATA_SCIENCE/09_ML_toolbox_numpy_%26_visulization/bokeh_hindi.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> bokeh.io.output_notebook()
#
# ModuleNotFoundError: No module named 'bokeh'

# %%
# !pip install bokeh
# Out:
# ^C
# Collecting bokeh
#   Obtaining dependency information for bokeh from https://files.pythonhosted.org/packages/84/60/33f23dbb15fcd785d6287bdd6fa8c9d836dacb40e21c14aad41a57a0ec0f/bokeh-3.2.2-py3-none-any.whl.metadata
#   Downloading bokeh-3.2.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (2.11.2)
# Collecting contourpy>=1 (from bokeh)
#   Obtaining dependency information for contourpy>=1 from https://files.pythonhosted.org/packages/94/0a/5eb57dd395fade977786b2d2c98c2bee8234358794be44422fe58a719d42/contourpy-1.1.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading contourpy-1.1.0-cp310-cp310-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy>=1.16 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (1.22.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (21.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (1.3.5)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (9.1.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (6.1)
# Collecting xyzservices>=2021.09.1 (from bokeh)
#   Obtaining dependency information for xyzservices>=2021.09.1 from https://files.pythonhosted.org/packages/50/d7/2ca7f65c189aa71b5a9dfeaabc0b4ab8d50bead74a7863428c579737d625/xyzservices-2023.7.0-py3-none-any.whl.metadata
#   Downloading xyzservices-2023.7.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=2.9->bokeh) (1.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from packaging>=16.8->bokeh) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->bokeh) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\om bade\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.2->bokeh) (1.15.0)
# Downloading bokeh-3.2.2-py3-none-any.whl (7.8 MB)
#    ---------------------------------------- 7.8/7.8 MB 359.9 kB/s eta 0:00:00
# Downloading contourpy-1.1.0-cp310-cp310-win_amd64.whl (470 kB)
#    -------------------------------------- 470.4/470.4 kB 153.4 kB/s eta 0:00:00
# Downloading xyzservices-2023.7.0-py3-none-any.whl (56 kB)
#    ---------------------------------------- 56.7/56.7 kB 148.3 kB/s eta 0:00:00
# Installing collected packages: xyzservices, contourpy, bokeh
# Successfully installed bokeh-3.2.2 contourpy-1.1.0 xyzservices-2023.7.0
# DEPRECATION: block 0.0.5 has a non-standard dependency specifier numpy>=1<2. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of block or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bokeh.plotting import figure ,output_file , show
from bokeh.sampledata.iris import flowers

output_file('test.html')

p = figure(title = "test flower")
p.xaxis.axis_label = "paltel lenght"
p.yaxis.axis_label = "paltel widhth"
p.circle(flowers['petal_length'] , flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="823eb5b5-da60-49f4-bba4-9d73eec7658e" data-root-id="1002"></div>

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from bokeh.plotting import figure ,output_file , show
from bokeh.sampledata.iris import flowers

output_file('line.html')

p = figure(title = "line graph")
p.xaxis.axis_label = "x axis"
p.yaxis.axis_label = "y axis"
p.line(flowers['petal_length'] , flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="059f8a16-667e-4085-bd7e-99bf4d68a233" data-root-id="1222"></div>

# %%
x = [2,3,4,5,6]
y = [3,4,5,6,7]
output_file("line.html")
p = figure(title = "line plot")
p.line(x,y)
show(p)
# Out:
#   <div class="bk-root" id="cde1ea68-4695-43ed-8260-0355cb054597" data-root-id="1734"></div>

# %%
x = [2,3,4,5,6]
y = [3,4,5,6,7]
output_file("line.html")
p = figure(title = "line plot")
p.scatter(x,y,fill_color = 'red' , legend_label = 'red points',size = 20)
show(p)
# Out:
#   <div class="bk-root" id="90b1ca4b-4458-43b3-840f-1c0f0c22f557" data-root-id="2886"></div>
