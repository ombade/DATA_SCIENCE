# %% [markdown]
# ### Q1. What are the three measures of central tendency?
# Ans ->
# The three measures of central tendency are:
#
# 1. **Mean**:
#    The mean is the arithmetic average of a dataset. It is calculated by summing up all the data values and dividing by the number of values. The mean is sensitive to outliers and provides a measure of the "center" of the data.
#
# 2. **Median**:
#    The median is the middle value in a dataset when the values are arranged in order. If the dataset has an odd number of values, the median is the middle value. If the dataset has an even number of values, the median is the average of the two middle values. The median is less affected by outliers and provides a measure of the "typical" value.
#
# 3. **Mode**:
#    The mode is the value that appears most frequently in a dataset. It represents the most common value and is often used for categorical data.
#
# These measures help to summarize the central value or tendency of a dataset and provide insights into the distribution of data points.

# %% [markdown]
# ### Q2. What is the difference between the mean, median, and mode? How are they used to measure the central tendency of a dataset?
# Ans -> The mean, median, and mode are all measures of central tendency that describe the center or typical value of a dataset. They provide different ways of summarizing the data, and each measure is suitable for different scenarios based on the characteristics of the data distribution.
#
# **Mean**:
# - The mean is the arithmetic average of a dataset. It is calculated by summing up all the data values and dividing by the number of values.
# - The mean is sensitive to outliers because it takes into account every data point. A single extreme value can significantly affect the mean.
# - It's used to find the balance point of the data distribution, indicating where the values tend to cluster around.
#
# **Median**:
# - The median is the middle value in a dataset when the values are arranged in order.
# - The median is less affected by outliers compared to the mean. It is a better measure of central tendency when the data distribution is skewed or contains extreme values.
# - It's used to represent the "typical" value and divides the data into two halves: half of the values are greater than the median, and half are less.
#
# **Mode**:
# - The mode is the value that appears most frequently in a dataset.
# - The mode can be useful for identifying the most common value or category in the data. It's often used for categorical data.
# - A dataset can have one mode (unimodal), two modes (bimodal), or more (multimodal).
#
# In summary, the mean provides the average value but can be influenced by outliers. The median is the middle value and is less affected by outliers. The mode is the most frequent value and can be useful for categorical data. The choice of measure depends on the distribution and characteristics of the data. Using all three measures together can provide a comprehensive understanding of the central tendency of a dataset.

# %% [markdown]
# ### Q3. Measure the three measures of central tendency for the given height data:
# ans ->
# Height data: [178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5]
#
# **Mean (Average)**:
# Mean = (Sum of all values) / (Number of values)
# Mean = (178 + 177 + 176 + ... + 176.5) / 16
#
# Mean ≈ 176.64375
#
# **Median**:
# First, let's arrange the data in ascending order:
# [172.5, 175, 175, 176, 176, 176.2, 176.5, 177, 177, 177, 178, 178, 178, 178.2, 178.9, 179, 180]
#
# Since there are 16 data points, the median is the average of the 8th and 9th values:
# Median = (177 + 177) / 2
#
# Median = 177
#
# **Mode**:
# The mode is the value that appears most frequently in the dataset. In this case, there is no value that appears more than once, so the dataset has no mode.
#
# To summarize:
# - Mean ≈ 176.64375
# - Median = 177
# - Mode = No mode
#
# These measures provide insights into the central tendency of the height data. The mean gives an average height, the median gives a typical height value, and in this case, there is no mode since all values appear only once.

# %% [markdown]
# Q4. Find the standard deviation for the given data:
#
# [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]
# Ans -> To find the standard deviation for the given height data, we can follow these steps:
#
# 1. Calculate the mean (average) of the data.
# 2. Calculate the squared difference between each data point and the mean.
# 3. Find the average of the squared differences.
# 4. Take the square root of the average of squared differences to get the standard deviation.
#
# Let's perform the calculations:
#
# Height data: [178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5]
#
# Step 1: Calculate the mean
# Mean = (178 + 177 + 176 + ... + 176.5) / 16
# Mean ≈ 176.64375
#
# Step 2: Calculate squared differences from the mean
# Squared differences = [(178 - Mean)^2, (177 - Mean)^2, ..., (176.5 - Mean)^2]
#
# Step 3: Find the average of squared differences
# Average of squared differences ≈ 3.130599609375
#
# Step 4: Calculate the square root to get the standard deviation
# Standard deviation ≈ √(3.130599609375)
# Standard deviation ≈ 1.76993517159
#
# So, the standard deviation for the given height data is approximately 1.7699.

# %% [markdown]
# ### Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe the spread of a dataset? Provide an example.
# Ans -> Measures of dispersion, such as range, variance, and standard deviation, are used to quantify the spread or variability of data points within a dataset. They provide insights into how much individual data points deviate from the central tendency measures (mean, median, etc.) and how spread out the values are from each other. These measures help in understanding the distribution and characteristics of the data.
#
# **Range**:
# The range is the simplest measure of dispersion and represents the difference between the maximum and minimum values in the dataset. It gives an idea of the extent of spread between the most extreme values.
#
# Example: Consider a dataset of exam scores: [70, 75, 80, 85, 90]. The range is 90 - 70 = 20, indicating that the scores span a range of 20 points.
#
# **Variance**:
# Variance calculates the average of the squared differences between each data point and the mean. It measures how much the data points deviate from the mean on average. A higher variance implies greater variability.
#
# Example: Suppose we have a dataset of heights (in cm): [160, 162, 170, 168, 175]. To calculate variance:
# - Calculate the mean: (160 + 162 + 170 + 168 + 175) / 5 = 167
# - Calculate squared differences from the mean: [(160 - 167)^2, (162 - 167)^2, ..., (175 - 167)^2]
# - Calculate the average of squared differences: (27 + 25 + 9 + 1 + 64) / 5 = 25.2
#
# **Standard Deviation**:
# Standard deviation is the square root of the variance. It provides a more interpretable measure of dispersion compared to variance. A higher standard deviation indicates more spread in the data.
#
# Example: Using the calculated variance from the previous example (25.2), the standard deviation is the square root of 25.2, approximately 5.02 cm.
#
# In summary, measures of dispersion help describe the variability and spread of data points within a dataset. The range provides a basic view of spread, while variance and standard deviation offer more detailed insights into how much individual data points differ from the mean and from each other.

# %% [markdown]
# ### Q6. What is a Venn diagram?
# Ans -> A Venn diagram is a visual representation used to show the relationships between different sets or groups. It uses overlapping circles or other shapes to depict the shared and distinct elements among the sets. Venn diagrams are often employed to illustrate concepts of set theory, logic, and intersections between various categories or attributes.
#
# Key features of a Venn diagram include:
#
# 1. **Circles or Shapes**: Each circle or shape in the diagram represents a different set or category. The size of the circles may vary, depending on the data being represented.
#
# 2. **Overlapping Areas**: The overlapping regions of circles represent the elements that are common to multiple sets. These areas are used to show the intersections between the sets.
#
# 3. **Distinct Areas**: The non-overlapping parts of the circles show the elements unique to each set. These areas represent the differences between the sets.
#
# Venn diagrams can depict relationships between two or more sets. Common types include:
#
# - **Two-Set Venn Diagram**: It has two circles that overlap to show common elements and unique areas for each set.
# - **Three-Set Venn Diagram**: It has three circles, and the overlapping regions display elements shared between different pairs of sets and all three sets together.
# - **Multi-Set Venn Diagram**: It can have more than three sets, and the complexity increases as more sets are added.
#
# Venn diagrams are useful for visualizing concepts like intersections, unions, differences, and complements of sets. They are often used in fields such as mathematics, logic, statistics, and data analysis to simplify complex relationships and make them easier to understand visually.

# %% [markdown]
# ### Q7. For the two given sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10). Find:
# (i) 	A insersect B
# (ii)	A ⋃ B
# Ans-> Certainly! Let's find the intersection and union of the given sets A and B:
#
# Given sets:
# A = {2, 3, 4, 5, 6, 7}
# B = {0, 2, 6, 8, 10}
#
# **(i) Intersection (A ∩ B)**:
# The intersection of two sets includes all elements that are common to both sets.
#
# A ∩ B = {2, 6}
#
# So, the intersection of sets A and B is {2, 6}.
#
# **(ii) Union (A ∪ B)**:
# The union of two sets includes all unique elements from both sets, without duplicates.
#
# A ∪ B = {0, 2, 3, 4, 5, 6, 7, 8, 10}
#
# So, the union of sets A and B is {0, 2, 3, 4, 5, 6, 7, 8, 10}.

# %% [markdown]
# ### Q8. What do you understand about skewness in data?
# Ans -> Skewness is a statistical measure that describes the asymmetry or lack of symmetry in the distribution of data points within a dataset. It indicates the extent to which the data is skewed or tilted towards one tail of the distribution, relative to the other tail. Skewness is an important aspect of data analysis as it provides insights into the shape and characteristics of the data distribution.
#
# There are three main types of skewness:
#
# 1. **Positive Skew (Right Skew)**:
#    In a positively skewed distribution, the tail on the right side (higher values) is longer or more spread out than the tail on the left side (lower values). This indicates that the majority of data points are concentrated towards the lower values, while a few higher values extend the right tail.
#
# 2. **Negative Skew (Left Skew)**:
#    In a negatively skewed distribution, the tail on the left side (lower values) is longer or more spread out than the tail on the right side (higher values). This suggests that the majority of data points are concentrated towards the higher values, while a few lower values extend the left tail.
#
# 3. **Symmetrical (No Skew)**:
#    In a symmetrical distribution, both tails are roughly equal in length and mirror each other. This means that the data is evenly distributed around the central point.
#
# Skewness can be quantified using a skewness coefficient or index. The skewness coefficient can be calculated to provide a numerical measure of the skewness in the data distribution. A positive skewness coefficient indicates positive skew, a negative skewness coefficient indicates negative skew, and a skewness coefficient of 0 indicates a symmetrical distribution.
#
# Understanding skewness is important because it affects the choice of statistical analyses and modeling techniques. Skewed data may require different approaches to analysis compared to symmetrical data. For example, positively skewed data may benefit from transformations to make the distribution more symmetrical before applying certain statistical tests.
#
# Overall, skewness provides valuable information about the shape of data distributions and helps analysts interpret and process data accurately.

# %% [markdown]
# ### Q9. If a data is right skewed then what will be the position of median with respect to mean?
# Ans -> If a dataset is right-skewed (positively skewed), it means that the tail of the distribution is longer on the right side (higher values) than on the left side (lower values). In this case, the majority of data points are concentrated towards the lower values, and a few higher values extend the right tail of the distribution.
#
# The position of the median with respect to the mean in a right-skewed distribution is as follows:
#
# 1. **Median**:
#    The median is the middle value in a dataset when the values are arranged in order. Since a right-skewed distribution has a longer right tail, the few higher values in the right tail can pull the median towards the higher values. This means that the median will be greater than the mean.
#
# 2. **Mean**:
#    The mean is the arithmetic average of the dataset. Because the mean is sensitive to outliers and higher values in the right tail can have a disproportionate impact, the mean will be pulled towards the higher values in a right-skewed distribution.
#
# In summary, in a right-skewed distribution:
# - The median will be greater than the mean.
# - The longer right tail, consisting of higher values, affects both the median and the mean, but the median is less affected by extreme values compared to the mean.

# %% [markdown]
# ### Q10. Explain the difference between covariance and correlation. How are these measures used in statistical analysis?
# Ans -> **Covariance** and **correlation** are both measures used to quantify the relationship between two variables in a dataset, but they capture different aspects of this relationship.
#
# **Covariance**:
# - Covariance measures how two variables change together. It indicates whether an increase in one variable is associated with an increase or decrease in another variable.
# - A positive covariance suggests that when one variable increases, the other variable tends to increase as well. A negative covariance suggests that when one variable increases, the other variable tends to decrease.
# - Covariance is affected by the scale of the variables, making it difficult to interpret on its own.
#
# **Correlation**:
# - Correlation measures the strength and direction of the linear relationship between two variables. It ranges from -1 (perfect negative correlation) to 1 (perfect positive correlation), with 0 indicating no linear correlation.
# - Correlation not only indicates the direction of the relationship (positive or negative) but also quantifies how closely the relationship follows a linear pattern.
# - Correlation is dimensionless and is not affected by the scale of the variables. It provides a standardized measure that is easier to interpret than covariance.
#
# **Use in Statistical Analysis**:
# Covariance and correlation are used in statistical analysis to understand the relationship between two variables and to assess the strength of their association. They are commonly employed in various fields, including finance, economics, biology, and social sciences.
#
# - **Covariance**:
#   Covariance is used to identify the direction of the relationship between variables. It indicates whether the variables tend to move in the same or opposite directions. However, without considering the scale, interpreting the magnitude of covariance can be challenging.
#
# - **Correlation**:
#   Correlation is used to assess the strength and direction of the linear relationship between variables. A correlation coefficient of close to 1 (positive) or -1 (negative) indicates a strong linear relationship, while a correlation coefficient close to 0 indicates weak or no linear relationship. Correlation is more widely used due to its standardized and easily interpretable nature.
#
# In summary, both covariance and correlation provide insights into the relationship between variables, but correlation is preferred in most cases due to its standardized nature and clear interpretation of the strength and direction of the relationship.

# %% [markdown]
# ### Q11. What is the formula for calculating the sample mean? Provide an example calculation for a dataset.
# Ans -> The formula for calculating the sample mean (average) of a dataset is:
#
# Sample Mean = (Sum of all data points) / (Number of data points)
#
# Here's an example calculation:
#
# Suppose you have the following dataset representing the scores of 5 students in a test:
# [85, 92, 78, 88, 95]
#
# Step 1: Add up all the data points:
# 85 + 92 + 78 + 88 + 95 = 438
#
# Step 2: Count the number of data points:
# There are 5 data points.
#
# Step 3: Calculate the sample mean:
# Sample Mean = 438 / 5
# Sample Mean = 87.6
#
# So, the sample mean for the given dataset is 87.6, which represents the average score of the 5 students in the test.

# %% [markdown]
# ### Q12. For a normal distribution data what is the relationship between its measure of central tendency?
# Ans -> For a normal distribution (also known as a Gaussian distribution), which is a symmetric and bell-shaped distribution, the measures of central tendency (mean, median, and mode) are all equal and located at the center of the distribution. This property holds true regardless of the specific values within the dataset. In other words, for a perfectly normal distribution:
#
# - The mean is equal to the median.
# - The mode is also equal to the mean and the median.
#
# This characteristic is one of the defining features of a normal distribution. The symmetry of the distribution ensures that the mean, median, and mode are located at the same point, right in the center of the distribution's peak.
#
# In practice, however, real-world data might not perfectly follow a normal distribution due to factors such as sampling variability or the influence of outliers. In such cases, while the measures of central tendency may still be close to each other, they might not be exactly equal. Nevertheless, for sufficiently large datasets that are close to normally distributed, the measures of central tendency tend to be very similar.

# %% [markdown]
# ### Q13. How is covariance different from correlation?
# Ans -> **Covariance** and **correlation** are both statistical measures used to describe the relationship between two variables, but they have some key differences:
#
# **Covariance**:
# - Covariance measures the extent to which two variables change together. It indicates whether an increase in one variable is associated with an increase or decrease in another variable.
# - A positive covariance suggests that both variables tend to increase or decrease together. A negative covariance suggests that one variable tends to increase while the other decreases.
# - The magnitude of covariance is not standardized and depends on the units of the variables. This makes it difficult to compare covariances across different datasets.
# - Covariance doesn't provide information about the strength or direction of the relationship between variables in a standardized way.
#
# **Correlation**:
# - Correlation measures the strength and direction of the linear relationship between two variables. It provides a standardized measure of how closely the relationship follows a linear pattern.
# - Correlation values range from -1 to 1. A correlation of 1 indicates a perfect positive linear relationship, -1 indicates a perfect negative linear relationship, and 0 indicates no linear relationship.
# - Correlation is unitless, meaning it is not affected by the units of the variables, making it more easily interpretable and comparable across different datasets.
# - Correlation provides insights into both the strength and direction of the relationship between variables.
#
# In summary, while both covariance and correlation measure the relationship between two variables, correlation provides a standardized measure that is more interpretable and comparable across different datasets. Covariance doesn't provide a standardized measure and is influenced by the units of the variables, making it less straightforward to interpret and compare. Correlation is particularly useful when assessing linear relationships between variables and understanding the degree to which they move together.

# %% [markdown]
# ### Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.
# Ans ->
# **Outliers** are data points that significantly deviate from the rest of the data in a dataset. They can have a notable impact on both measures of central tendency (mean, median, mode) and measures of dispersion (range, variance, standard deviation). Here's how outliers can affect these measures, along with an example:
#
# **Measures of Central Tendency**:
# 1. **Mean**:
#    Outliers can heavily influence the mean, pulling it in the direction of the outlier's value. The mean is not robust to outliers and can be skewed by their presence.
#
# 2. **Median**:
#    The median is less affected by outliers compared to the mean. It represents the middle value in the dataset, so outliers have less impact on its value.
#
# 3. **Mode**:
#    The mode is generally not affected by outliers since it represents the most frequently occurring value, which might remain unchanged despite the presence of outliers.
#
# **Measures of Dispersion**:
# 1. **Range**:
#    Outliers can significantly affect the range by stretching it towards the extreme values represented by the outliers.
#
# 2. **Variance and Standard Deviation**:
#    Outliers can greatly influence the variance and standard deviation. Since these measures involve the squared differences between data points and the mean, an outlier's large squared difference can inflate these measures.
#
# **Example**:
# Consider the following dataset of exam scores (out of 100):
# [75, 85, 90, 92, 95, 98, 100, 105]
#
# - **Mean**: The mean is affected by the outlier (105). Calculating the mean:
#    Mean = (75 + 85 + 90 + 92 + 95 + 98 + 100 + 105) / 8
#    Mean ≈ 93.875
#
# - **Median**: The median is less affected by the outlier. Arranging the data in order:
#    [75, 85, 90, 92, 95, 98, 100, 105]
#    Median = (95 + 98) / 2
#    Median = 96.5
#
# - **Variance and Standard Deviation**: The outlier's influence is stronger on variance and standard deviation due to the squared differences:
#    Variance ≈ 97.4
#    Standard Deviation ≈ 9.87
#
# In this example, the outlier (105) affects the mean, variance, and standard deviation, while the median and mode remain relatively unchanged. Outliers can distort the measures of central tendency and dispersion, making it important to consider their presence and assess the robustness of the chosen measures to outliers.
