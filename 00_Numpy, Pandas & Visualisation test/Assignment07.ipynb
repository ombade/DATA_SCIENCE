# %% [markdown]
# **Here use the dataset: "Assignment01.csv" for the given task. Load the dataset in a pandas DataFrame and apply the following task:**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Datasets\Assignment07.csv")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12-01-2010 08:26       2.55     17850.0  United Kingdom
# 1  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 2  12-01-2010 08:26       2.75     17850.0  United Kingdom
# 3  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 4  12-01-2010 08:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ### **Task-1:**
#
# Find the most ordered item in the given dataframe.

# %%
most_ordered_item = df["Description"].value_counts().index[0]
print(f"Item: {most_ordered_item}, have been ordered {df['Description'].value_counts()[0]}")
# Out:
# Item: WHITE HANGING HEART T-LIGHT HOLDER, have been ordered 2369

# %% [markdown]
# ### **Task-2:**
#
# Find the item, with net heighest number of quantity been sold.

# %%
print(f"Item with the highest quantity sold is {df.groupby('Description')['Quantity'].sum().sort_values(ascending= False).index[0]} with number of quantity sold : {df.groupby('Description')['Quantity'].sum().max()}")
# Out:
# Item with the highest quantity sold is WORLD WAR 2 GLIDERS ASSTD DESIGNS with number of quantity sold : 53847

# %% [markdown]
# ### **Task-3:**
#
# Find the number of orders placed on '12-07-2011' and total quantity sold on this date.

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
#Creating separate dataframe
filtered_df = df[df['InvoiceDate'].dt.date == pd.to_datetime('12-07-2011').date()]

# %%
#Coping the dataframe
print(f"On 12-07-2011, {len(filtered_df)} orders were placed and total {filtered_df['Quantity'].sum()} quantity of items were sold.")
# Out:
# On 12-07-2011, 2438 orders were placed and total 39612 quantity of items were sold.

# %% [markdown]
# ### **Task-4:**
#
# Plot the number of orders placed with respect to each country.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
order_by_country = df.groupby('Country').sum()

order_by_country.plot(kind='bar', color='skyblue', edgecolor='black')

# Adding labels and title
plt.xlabel('Country')
plt.ylabel('Net Orders')
plt.title('Net Orders Placed in Different Countries')

# Display the plot
plt.show()
# Out:
# C:\Users\KUSHAL\AppData\Local\Temp\ipykernel_27820\2584021241.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   order_by_country = df.groupby('Country').sum()

# %% [markdown]
# ### **Task-5:**
#
# Find the CustomerID of the person having the net highest number of quantity.

# %%
df_customer_id = df.groupby('CustomerID')['Quantity'].sum()

# %%
df_customer_id.idxmax()
# Out:
# 14646.0
